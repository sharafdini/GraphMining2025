# %%
import graph_tool.all as gt
g = gt.collection.ns["lesmis"]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import graph_tool.all as gt
#       2 g = gt.collection.ns["lesmis"]
#
# ModuleNotFoundError: No module named 'graph_tool'

# %%
pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.6.2.post1
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     24.2.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# certifi                   2024.8.30
# cffi                      1.17.1
# charset-normalizer        3.4.0
# colorama                  0.4.6
# comm                      0.2.2
# contourpy                 1.3.0
# cycler                    0.12.1
# debugpy                   1.8.7
# decorator                 5.1.1
# defusedxml                0.7.1
# executing                 2.1.0
# fastjsonschema            2.20.0
# fonttools                 4.54.1
# fqdn                      1.5.1
# graph-tool-nn             1.1.0
# h11                       0.14.0
# ...

# %%
import networkx as nx

# %%
G = nx.read_gml("lesmis.gml", destringizer=int)

# %%
nx.draw(G,with_labels=False)
