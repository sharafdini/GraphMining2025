# %%
import pgu

pgu.country
# Out:
# 'IRAN'

# %%
pgu.salam('Iraq')
# Out:
# 'Salam, How are you?, I am from Iraq'

# %%
pgu.salam()
# Out:
# 'Salam, How are you?, I am from IRAN'

# %%
pgu._salam()
# Out:
# 'Salam, How are you?, I am from IRAN'

# %%
pgu._salam('Iraq')
# Out:
# 'Salam, How are you?, I am from Iraq'

# %%
G1 = pgu.gigili()

G1.hi()
# Out:
# Salam, esme man IRAN

# %%
pgu.salam(G1.bye())
# Out:
# 'Salam, How are you?, I am from IRAN'
